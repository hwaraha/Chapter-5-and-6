# %%
list(filter(lambda x:x>0, [1, -2, 3, -5, 8, -3]))
# Out:
# [1, 3, 8]

# %%
int('0xea', 16)
# Out:
# 234

# %%
list(map(lambda x:x*3, [1,2,3,4]))
# Out:
# [3, 6, 9, 12]

# %%
a = [-8, 2, 7, 5, -3, 5, 0, 1]
max(a) + min(a)
# Out:
# -1

# %%
round(17/3, 4)
# Out:
# 5.6667
